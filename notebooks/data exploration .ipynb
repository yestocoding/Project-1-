# %%
import glob
import os
import pandas as pd

# Path to your raw data directory relative to the notebooks/ folder
data_dir = "../data/raw"

# Find all CSV files in data/raw
csv_files = glob.glob(os.path.join(data_dir, "*.csv"))

# Store loaded DataFrames in a dictionary
dataframes = {}

print(f"Found {len(csv_files)} CSV files.\n" + "=" * 50)

for file_path in sorted(csv_files):
    file_name = os.path.basename(file_path)
    df_name = os.path.splitext(file_name)[0]

    # Load dataset
    df = pd.read_csv(file_path)
    dataframes[df_name] = df

    # Print summary information
    print(f"\n DATASET: {file_name}")
    print("-" * 50)

    print("\n1️⃣ SHAPE (Rows, Columns):")
    print(df.shape)

    print("\n2️⃣ DATA TYPES:")
    print(df.dtypes)

    print("\n3️⃣ HEAD (First 5 Rows):")
    display(df.head())  # Using display() gives a clean tabular rendering in Jupyter

    print("\n" + "=" * 50)
# Out:
# Found 10 CSV files.
# ...
#
#  DATASET: 01_fund_master.csv
# --------------------------------------------------
#
# 1️⃣ SHAPE (Rows, Columns):
# (40, 15)
#
# 2️⃣ DATA TYPES:
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
#
# 3️⃣ HEAD (First 5 Rows):
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# ...

# %%
import os

print("Current Working Directory:", os.getcwd())
print("Files in current directory:", os.listdir('.'))

# Check if data/raw exists from here
if os.path.exists("../data/raw"):
    print("Found ../data/raw! Contents:", os.listdir("../data/raw"))
elif os.path.exists("data/raw"):
    print("Found data/raw! Contents:", os.listdir("data/raw"))
else:
    print("Could not find data/raw from this directory.")
# Out:
# Current Working Directory: C:\Users\hp\my-project\notebooks
# Files in current directory: ['.gitkeep', '.ipynb_checkpoints', 'data exploration .ipynb']
# Found ../data/raw! Contents: ['.gitkeep', '01_fund_master.csv', '02_nav_history.csv', '03_aum_by_fund_house.csv', '04_monthly_sip_inflows.csv', '05_category_inflows.csv', '06_industry_folio_count.csv', '07_scheme_performance.csv', '08_investor_transactions.csv', '09_portfolio_holdings.csv', '10_benchmark_indices.csv']

# %%
import os
print("Files in this directory:", os.listdir())

# %%
import os
print("Current folder:", os.getcwd())
print("Files/folders here:", os.listdir())
# Out:
# Current folder: C:\Users\hp\my-project\notebooks
# Files/folders here: ['.gitkeep', '.ipynb_checkpoints', 'data exploration .ipynb']
